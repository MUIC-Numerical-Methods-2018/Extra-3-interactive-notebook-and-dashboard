# %%
from matplotlib import pyplot as plt

im = plt.imread('mario.png')
im.shape
# Out:
# (480, 381, 4)

# %%
im_rgb = im[:, :, :3]

# %%
im_rgb.shape
# Out:
# (480, 381, 3)

# %%
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
im = plt.imread('mario.png')
im_rgb = im[:, :, :3]
hsv = mpl.colors.rgb_to_hsv(im_rgb)
mask = (hsv[:,:,0] > 0.8) | (hsv[:,:,0] < 0.01)
print(mask.shape)
print(np.sum(mask))
hsv[mask]=0.5
new_rgb = mpl.colors.hsv_to_rgb(hsv)
plt.imshow(new_rgb)
# Out:
# (480, 381)
# 102057

# %%
plt.hist(hsv[:,:,0])
# Out:
# (array([[461.,   0.,   0., ...,   0.,   0.,   0.],
#         [451.,   0.,   0., ...,   0.,   0.,   0.],
#         [444.,   0.,   0., ...,   0.,   0.,   0.],
#         ...,
#         [480.,   0.,   0., ...,   0.,   0.,   0.],
#         [480.,   0.,   0., ...,   0.,   0.,   0.],
#         [480.,   0.,   0., ...,   0.,   0.,   0.]]),
#  array([0.        , 0.09992722, 0.19985445, 0.29978168, 0.3997089 ,
#         0.4996361 , 0.59956336, 0.69949055, 0.7994178 , 0.899345  ,
#         0.9992722 ], dtype=float32),
#  <a list of 381 BarContainer objects>)
